# %% [markdown]
# # Pair Programming ANOVA

# %% [markdown]
# En el pair programming de hoy usaremos el set de datos que guardastéis en el pair programming de normalización y estandarización.

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd
import random 

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Estadísticos
# ------------------------------------------------------------------------------
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA
from sklearn.preprocessing import StandardScaler

plt.rcParams["figure.figsize"] = (10,8)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv("data/df_norm_estand.csv", index_col = 0)
df.sample(5)
# Out:
#       age     sex   bmi  children smoker     region    charges  \
# 1051   22  female  27.1         0     no  southwest   2154.361
# 757    51  female  34.2         1     no  southwest   9872.701
# 566    51    male  39.7         1     no  southwest   9391.346
# 743    63    male  33.1         0     no  southwest  13393.756
# 829    19  female  23.4         2     no  southwest   2913.569
#
#       charges_Sklearn  age_robust  bmi_robust  children_robust
# 1051         0.030958       -0.68   -0.328554             -0.5
# 757          0.262386        0.48    0.556733              0.0
# 566          0.247953        0.48    1.242519              0.0
# 743          0.367962        0.96    0.419576             -0.5
# 829          0.053722       -0.80   -0.789900              0.5

# %% [markdown]
# ### Empezamos con el método OLS

# %%
lm = ols('charges_Sklearn ~ age + sex + bmi + children + smoker + region',data = df).fit()

# %%
sm.stats.anova_lm(lm)
# Out:
#               df     sum_sq    mean_sq            F         PR(>F)
# sex          1.0   0.030904   0.030904     1.645281   1.998524e-01
# smoker       1.0  20.484783  20.484783  1090.577381  2.986538e-170
# region       3.0   0.232534   0.077511     4.126584   6.360910e-03
# age          1.0  12.904397  12.904397   687.009633  6.904498e-120
# bmi          1.0   0.155038   0.155038     8.253995   4.138508e-03
# children     1.0   0.272009   0.272009    14.481332   1.487623e-04
# Residual  1189.0  22.333497   0.018783          NaN            NaN

# %% [markdown]
# SI miramos el p-valor, al ser todos menores que el 0.05 rechazamos la H0 (que dice que la variable no tiene efecto sobre la variable respuesta) y vemos que todas influyen en la variable respuesta.

# %% [markdown]
# ## Método summary

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        charges_Sklearn   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     226.8
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):          4.49e-233
# Time:                        19:44:04   Log-Likelihood:                 685.52
# No. Observations:                1198   AIC:                            -1353.
# Df Residuals:                    1189   BIC:                            -1307.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.1199      0.024     -4.919      0.000      -0.168      -0.072
# sex[T.male]            -0.0109      0.008     -1.374      0.170      -0.026       0.005
# smoker[T.yes]           0.4391      0.013     34.116      0.000       0.414       0.464
# region[T.northwest]    -0.0082      0.011     -0.737      0.461      -0.030       0.014
# region[T.southeast]    -0.0315      0.011     -2.736      0.006      -0.054      -0.009
# region[T.southwest]    -0.0393      0.011     -3.458      0.001      -0.062      -0.017
# age                     0.0073      0.000     25.540      0.000       0.007       0.008
# bmi                     0.0020      0.001      2.875      0.004       0.001       0.003
# children                0.0124      0.003      3.805      0.000       0.006       0.019
# ==============================================================================
# Omnibus:                      750.552   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5243.984
# Skew:                           3.011   Prob(JB):                         0.00
# Kurtosis:                      11.294   Cond. No.                         322.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# El r-squared es el porcentaje de variación de la variable respuesta. En nuestro caso tenemos un 0.60, lo que significa que nuestras variables predictoras explican el 60% de la variación de los precios de nuestro seguro médico.
#
# El coef nos indica los cambios medios en la variable respuesta para una unidad de cambio en la variable predictora
#
# El p.valor nos dice que nuestras variables influyen, son menores que 0.05 menos en sex y region. Asi que cogeríamos todas nuestras variables menos esas dos.
#
# El std err es el error estándar del coeficiente y cuanto menor sea, más preciso. En nuestro caso son todos pequeños.

# %% [markdown]
# ## Vamos a ver con efectos aditivos
# Omitimos las interpretaciones ya que solo lo hemos hecho para ver este método.

# %%
lm = ols('charges_Sklearn ~ age_robust * bmi_robust * children_robust * smoker * sex * region',data = df).fit()

# %%
sm.stats.anova_lm(lm)
# Out:
#                                                         df     sum_sq  \
# smoker                                                 1.0  20.460507
# sex                                                    1.0   0.055180
# region                                                 3.0   0.232534
# smoker:sex                                             1.0   0.008091
# smoker:region                                          3.0   0.128678
# ...                                                    ...        ...
# age_robust:bmi_robust:children_robust:smoker:sex       1.0   0.011157
# age_robust:bmi_robust:children_robust:smoker:re...     3.0   0.013274
# age_robust:bmi_robust:children_robust:sex:region       3.0   0.040479
# age_robust:bmi_robust:children_robust:smoker:se...     3.0   0.089021
# Residual                                            1070.0  18.688403
#
#                                                       mean_sq            F  \
# smoker                                              20.460507  1171.461422
# sex                                                  0.055180     3.159309
# region                                               0.077511     4.437896
# smoker:sex                                           0.008091     0.463231
# smoker:region                                        0.042893     2.455809
# ...                                                       ...          ...
# age_robust:bmi_robust:children_robust:smoker:sex     0.011157     0.638804
# age_robust:bmi_robust:children_robust:smoker:re...   0.004425     0.253328
# age_robust:bmi_robust:children_robust:sex:region     0.013493     0.772537
# age_robust:bmi_robust:children_robust:smoker:se...   0.029674     1.698957
# Residual                                             0.017466          NaN
#
#                                                            PR(>F)
# smoker                                              5.173345e-174
# sex                                                  7.577911e-02
# region                                               4.149743e-03
# smoker:sex                                           4.962651e-01
# smoker:region                                        6.166103e-02
# ...                                                           ...
# age_robust:bmi_robust:children_robust:smoker:sex     4.243216e-01
# age_robust:bmi_robust:children_robust:smoker:re...   8.589923e-01
# age_robust:bmi_robust:children_robust:sex:region     5.094273e-01
# age_robust:bmi_robust:children_robust:smoker:se...   1.655262e-01
# Residual                                                      NaN
#
# [64 rows x 5 columns]

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:
# bmi_robust:children_robust:sex[T.male]:region[T.southeast]                             -0.0668      0.055     -1.216      0.224      -0.175       0.041
# bmi_robust:children_robust:sex[T.male]:region[T.southwest]                             -0.0295      0.057     -0.519      0.604      -0.141       0.082
# bmi_robust:children_robust:smoker[T.yes]:sex[T.male]:region[T.northwest]                1.4328      0.841      1.703      0.089      -0.218       3.084
# bmi_robust:children_robust:smoker[T.yes]:sex[T.male]:region[T.southeast]                0.4486      0.598      0.750      0.454      -0.725       1.623
# bmi_robust:children_robust:smoker[T.yes]:sex[T.male]:region[T.southwest]                0.8878      0.522      1.700      0.089      -0.137       1.913
# age_robust:bmi_robust:children_robust                                                   0.1333      0.070      1.900      0.058      -0.004       0.271
# age_robust:bmi_robust:children_robust:smoker[T.yes]                                    -0.2494      0.610     -0.408      0.683      -1.447       0.948
# age_robust:bmi_robust:children_robust:sex[T.male]                                      -0.1321      0.096     -1.375      0.169      -0.321       0.056
# age_robust:bmi_robust:children_robust:region[T.northwest]                              -0.1085      0.090     -1.203      0.229      -0.286       0.069
# age_robust:bmi_robust:children_robust:region[T.southeast]                              -0.1364      0.088     -1.549      0.122      -0.309       0.036
# age_robust:bmi_robust:children_robust:region[T.southwest]                              -0.1384      0.086     -1.615      0.107      -0.307       0.030
# age_robust:bmi_robust:children_robust:smoker[T.yes]:sex[T.male]                         0.5766      0.640      0.901      0.368      -0.679       1.832
# age_robust:bmi_robust:children_robust:smoker[T.yes]:region[T.northwest]                 0.0995      0.892      0.112      0.911      -1.651       1.850
# age_robust:bmi_robust:children_robust:smoker[T.yes]:region[T.southeast]                 0.6414      0.787      0.815      0.415      -0.902       2.185
# age_robust:bmi_robust:children_robust:smoker[T.yes]:region[T.southwest]                -7.9888      4.857     -1.645      0.100     -17.519       1.541
# age_robust:bmi_robust:children_robust:sex[T.male]:region[T.northwest]                   0.1064      0.128      0.829      0.408      -0.146       0.358
# age_robust:bmi_robust:children_robust:sex[T.male]:region[T.southeast]                   0.1498      0.126      1.187      0.235      -0.098       0.397
# age_robust:bmi_robust:children_robust:sex[T.male]:region[T.southwest]                   0.1801      0.119      1.515      0.130      -0.053       0.413
# age_robust:bmi_robust:children_robust:smoker[T.yes]:sex[T.male]:region[T.northwest]     1.0093      1.437      0.702      0.483      -1.811       3.829
# age_robust:bmi_robust:children_robust:smoker[T.yes]:sex[T.male]:region[T.southeast]    -0.8654      0.920     -0.941      0.347      -2.670       0.940
# age_robust:bmi_robust:children_robust:smoker[T.yes]:sex[T.male]:region[T.southwest]     8.3200      4.878      1.706      0.088      -1.252      17.892
# ==============================================================================
# Omnibus:                      768.450   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6249.407
# Skew:                           3.024   Prob(JB):                         0.00
# Kurtosis:                      12.414   Cond. No.                     3.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Vemos con efectos no aditivos pero con el Robust

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'charges_Sklearn', 'age_robust', 'bmi_robust', 'children_robust'],
#       dtype='object')

# %%
lm = ols('charges_Sklearn ~ age_robust + bmi_robust + children_robust + smoker + sex + region',data = df).fit()

# %%
sm.stats.anova_lm(lm)
# Out:
#                      df     sum_sq    mean_sq            F         PR(>F)
# smoker              1.0  20.460507  20.460507  1089.284975  4.185267e-170
# sex                 1.0   0.055180   0.055180     2.937688   8.679514e-02
# region              3.0   0.232534   0.077511     4.126584   6.360910e-03
# age_robust          1.0  12.904397  12.904397   687.009633  6.904498e-120
# bmi_robust          1.0   0.155038   0.155038     8.253995   4.138508e-03
# children_robust     1.0   0.272009   0.272009    14.481332   1.487623e-04
# Residual         1189.0  22.333497   0.018783          NaN            NaN

# %% [markdown]
# Igual que antes, parece que todas nuestras variables tienen efecto osbre la respuesta, al ser menor que 0.05.

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        charges_Sklearn   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     226.8
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):          4.49e-233
# Time:                        19:44:06   Log-Likelihood:                 685.52
# No. Observations:                1198   AIC:                            -1353.
# Df Residuals:                    1189   BIC:                            -1307.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.2368      0.009     26.272      0.000       0.219       0.255
# smoker[T.yes]           0.4391      0.013     34.116      0.000       0.414       0.464
# sex[T.male]            -0.0109      0.008     -1.374      0.170      -0.026       0.005
# region[T.northwest]    -0.0082      0.011     -0.737      0.461      -0.030       0.014
# region[T.southeast]    -0.0315      0.011     -2.736      0.006      -0.054      -0.009
# region[T.southwest]    -0.0393      0.011     -3.458      0.001      -0.062      -0.017
# age_robust              0.1817      0.007     25.540      0.000       0.168       0.196
# bmi_robust              0.0164      0.006      2.875      0.004       0.005       0.028
# children_robust         0.0249      0.007      3.805      0.000       0.012       0.038
# ==============================================================================
# Omnibus:                      750.552   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5243.984
# Skew:                           3.011   Prob(JB):                         0.00
# Kurtosis:                      11.294   Cond. No.                         5.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Intepretación

# %% [markdown]
# El r-squared es el porcentaje de la variacion de la variable respuesta. ES decir, nuestras variables predictoras explican el 60,4% de la variacion en los precios del seguro medico (charges). ES un valor bajo.
#
# El coef nos indica los cambios medios en la variable respuesta para una unidad de cambio en la variable predictora. Age, bmi y children tienen un coeficiente positivo, a mayor edad, bmi o hijos, mayores primas. Todas tienen una relación postiva, menos las de 'region', que es negativa.
#
# El p.valor nos dice que nuestras variables influyen, son menores que 0.05 menos en sex y region. Asi que cogeríamos todas nuestras variables menos esas dos.
#
# El std err es el error estándar del coeficiente y cuanto menor sea, más preciso. En nuestro caso son todos bastante bajos.

# %% [markdown]
# ### En  conclusión, vemos que las variables region y sex  no influyen en la variable respuesta. Llegado el momento de hacer la regresión, las eliminaremos del dataframe para ajustar mejor el modelo.

# %%
df2.to_csv('data/df_tras_anova.csv')
